# %% [markdown]
# int 1,2,3,4,5
#
# 内存：连续的存储空间
#
# 基本单位：
# ![image.png](attachment:image.png)

# %% [markdown]
# list tuple 都是顺序表
#
# list：采用分离式技术实现的动态顺序表
#
# 存储区扩充：动态顺序表
#
# 扩充策略：8个元素存储区，插入满的话，换4倍，当>50000，就一倍
#
# 下标：偏移量
# ![image.png](attachment:image.png)

# %% [markdown]
# 顺序表：表头信息[容量、元素个数]，数据库
#
# 两种实现方式：一体式：max、num 元素存储区。分离式：利于扩展
#
# ![image.png](attachment:image.png)
